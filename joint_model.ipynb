# %% [markdown]
# <a href="https://colab.research.google.com/github/HANKSOONG/image-repair-and-restoration-/blob/main/joint_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Colab Notebooks/GOPRO_Large.zip" -d "/content/datasets"
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000615.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000616.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000617.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000618.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000619.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000620.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000621.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000622.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000623.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000624.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000625.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000626.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000627.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000628.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000629.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000630.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000631.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000632.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000633.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000634.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000635.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000636.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000637.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000638.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000639.png
#   inflating: /content/datasets/train/GOPR0374_11_02/blur_gamma/000640.png
#  extracting: /content/datasets/train/GOPR0374_11_02/frames 11 offset 0.txt
#    creating: /content/datasets/train/GOPR0374_11_02/sharp/
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000541.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000542.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000543.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000544.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000545.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000546.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000547.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000548.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000549.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000550.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000551.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000552.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000553.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000554.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000555.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000556.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000557.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000558.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000559.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000560.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000561.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000562.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000563.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000564.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000565.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000566.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000567.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000568.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000569.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000570.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000571.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000572.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000573.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000574.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000575.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000576.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000577.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000578.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000579.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000580.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000581.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000582.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000583.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000584.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000585.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000586.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000587.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000588.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000589.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000590.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000591.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000592.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000593.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000594.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000595.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000596.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000597.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000598.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000599.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000600.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000601.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000602.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000603.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000604.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000605.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000606.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000607.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000608.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000609.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000610.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000611.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000612.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000613.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000614.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000615.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000616.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000617.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000618.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000619.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000620.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000621.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000622.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000623.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000624.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000625.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000626.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000627.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000628.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000629.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000630.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000631.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000632.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000633.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000634.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000635.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000636.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000637.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000638.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000639.png
#   inflating: /content/datasets/train/GOPR0374_11_02/sharp/000640.png
#    creating: /content/datasets/train/GOPR0374_11_03/
#    creating: /content/datasets/train/GOPR0374_11_03/blur/
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002481.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002482.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002483.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002484.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002485.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002486.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002487.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002488.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002489.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002490.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002491.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002492.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002493.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002494.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002495.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002496.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002497.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002498.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002499.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002500.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002501.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002502.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002503.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002504.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002505.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002506.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002507.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002508.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002509.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002510.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002511.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002512.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002513.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002514.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002515.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002516.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002517.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002518.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002519.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002520.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002521.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002522.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002523.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002524.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002525.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002526.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002527.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur/002528.png
#    creating: /content/datasets/train/GOPR0374_11_03/blur_gamma/
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002481.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002482.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002483.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002484.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002485.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002486.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002487.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002488.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002489.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002490.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002491.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002492.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002493.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002494.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002495.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002496.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002497.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002498.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002499.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002500.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002501.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002502.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002503.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002504.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002505.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002506.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002507.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002508.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002509.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002510.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002511.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002512.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002513.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002514.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002515.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002516.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002517.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002518.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002519.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002520.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002521.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002522.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002523.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002524.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002525.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002526.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002527.png
#   inflating: /content/datasets/train/GOPR0374_11_03/blur_gamma/002528.png
#  extracting: /content/datasets/train/GOPR0374_11_03/frames 11 offset 0.txt
#    creating: /content/datasets/train/GOPR0374_11_03/sharp/
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002481.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002482.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002483.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002484.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002485.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002486.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002487.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002488.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002489.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002490.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002491.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002492.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002493.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002494.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002495.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002496.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002497.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002498.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002499.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002500.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002501.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002502.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002503.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002504.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002505.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002506.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002507.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002508.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002509.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002510.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002511.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002512.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002513.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002514.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002515.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002516.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002517.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002518.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002519.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002520.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002521.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002522.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002523.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002524.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002525.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002526.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002527.png
#   inflating: /content/datasets/train/GOPR0374_11_03/sharp/002528.png
#    creating: /content/datasets/train/GOPR0378_13_00/
#    creating: /content/datasets/train/GOPR0378_13_00/blur/
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000041.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000042.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000043.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000044.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000045.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000046.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000047.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000048.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000049.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000050.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000051.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000052.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000053.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000054.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000055.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000056.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000057.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000058.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000059.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000060.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000061.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000062.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000063.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000064.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000065.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000066.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000067.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000068.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000069.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000070.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000071.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000072.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000073.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000074.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000075.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000076.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000077.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000078.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000079.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000080.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000081.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000082.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000083.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000084.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000085.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000086.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000087.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000088.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000089.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000090.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000091.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000092.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000093.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000094.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000095.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000096.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000097.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000098.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000099.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000100.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000101.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000102.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000103.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000104.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000105.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000106.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000107.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000108.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000109.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000110.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000111.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000112.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000113.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000114.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000115.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000116.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000117.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000118.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000119.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000120.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000121.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000122.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000123.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000124.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000125.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000126.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000127.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000128.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000129.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000130.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000131.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000132.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000133.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000134.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000135.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000136.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000137.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000138.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000139.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000140.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000141.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000142.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000143.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000144.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000145.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000146.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000147.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000148.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000149.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur/000150.png
#    creating: /content/datasets/train/GOPR0378_13_00/blur_gamma/
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000041.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000042.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000043.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000044.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000045.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000046.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000047.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000048.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000049.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000050.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000051.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000052.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000053.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000054.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000055.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000056.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000057.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000058.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000059.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000060.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000061.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000062.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000063.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000064.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000065.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000066.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000067.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000068.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000069.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000070.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000071.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000072.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000073.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000074.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000075.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000076.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000077.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000078.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000079.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000080.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000081.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000082.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000083.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000084.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000085.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000086.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000087.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000088.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000089.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000090.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000091.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000092.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000093.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000094.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000095.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000096.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000097.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000098.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000099.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000100.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000101.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000102.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000103.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000104.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000105.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000106.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000107.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000108.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000109.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000110.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000111.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000112.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000113.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000114.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000115.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000116.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000117.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000118.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000119.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000120.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000121.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000122.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000123.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000124.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000125.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000126.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000127.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000128.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000129.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000130.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000131.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000132.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000133.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000134.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000135.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000136.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000137.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000138.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000139.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000140.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000141.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000142.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000143.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000144.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000145.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000146.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000147.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000148.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000149.png
#   inflating: /content/datasets/train/GOPR0378_13_00/blur_gamma/000150.png
#  extracting: /content/datasets/train/GOPR0378_13_00/frames 13 offset 22000.txt
#    creating: /content/datasets/train/GOPR0378_13_00/sharp/
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000041.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000042.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000043.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000044.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000045.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000046.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000047.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000048.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000049.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000050.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000051.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000052.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000053.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000054.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000055.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000056.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000057.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000058.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000059.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000060.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000061.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000062.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000063.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000064.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000065.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000066.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000067.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000068.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000069.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000070.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000071.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000072.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000073.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000074.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000075.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000076.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000077.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000078.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000079.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000080.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000081.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000082.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000083.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000084.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000085.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000086.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000087.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000088.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000089.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000090.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000091.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000092.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000093.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000094.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000095.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000096.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000097.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000098.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000099.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000100.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000101.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000102.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000103.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000104.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000105.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000106.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000107.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000108.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000109.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000110.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000111.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000112.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000113.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000114.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000115.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000116.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000117.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000118.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000119.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000120.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000121.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000122.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000123.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000124.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000125.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000126.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000127.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000128.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000129.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000130.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000131.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000132.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000133.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000134.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000135.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000136.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000137.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000138.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000139.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000140.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000141.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000142.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000143.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000144.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000145.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000146.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000147.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000148.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000149.png
#   inflating: /content/datasets/train/GOPR0378_13_00/sharp/000150.png
#    creating: /content/datasets/train/GOPR0379_11_00/
#    creating: /content/datasets/train/GOPR0379_11_00/blur/
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000188.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000189.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000190.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000191.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000192.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000193.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000194.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000195.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000196.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000197.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000198.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000199.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000200.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000201.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000202.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000203.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000204.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000205.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000206.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000207.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000208.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000209.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000210.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000211.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000212.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000213.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000214.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000215.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000216.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000217.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000218.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000219.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000220.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000221.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000222.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000223.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000224.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000225.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000226.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000227.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000228.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000229.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000230.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000231.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000232.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000233.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000234.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000235.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000236.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000237.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000238.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000239.png
#   inflating: /content/datasets/train/GOPR0379_11_00/blur/000240.png
# ...
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000271.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000272.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000273.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000274.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000275.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000276.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000277.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000278.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000279.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000280.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000281.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000282.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000283.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000284.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur/000285.png
#    creating: /content/datasets/train/GOPR0884_11_00/blur_gamma/
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000186.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000187.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000188.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000189.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000190.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000191.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000192.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000193.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000194.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000195.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000196.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000197.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000198.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000199.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000200.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000201.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000202.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000203.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000204.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000205.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000206.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000207.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000208.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000209.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000210.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000211.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000212.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000213.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000214.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000215.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000216.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000217.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000218.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000219.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000220.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000221.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000222.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000223.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000224.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000225.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000226.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000227.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000228.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000229.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000230.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000231.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000232.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000233.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000234.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000235.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000236.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000237.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000238.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000239.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000240.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000241.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000242.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000243.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000244.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000245.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000246.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000247.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000248.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000249.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000250.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000251.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000252.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000253.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000254.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000255.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000256.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000257.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000258.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000259.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000260.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000261.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000262.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000263.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000264.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000265.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000266.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000267.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000268.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000269.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000270.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000271.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000272.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000273.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000274.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000275.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000276.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000277.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000278.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000279.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000280.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000281.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000282.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000283.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000284.png
#   inflating: /content/datasets/train/GOPR0884_11_00/blur_gamma/000285.png
#  extracting: /content/datasets/train/GOPR0884_11_00/frames 11 offset 0.txt
#    creating: /content/datasets/train/GOPR0884_11_00/sharp/
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000186.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000187.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000188.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000189.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000190.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000191.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000192.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000193.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000194.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000195.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000196.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000197.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000198.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000199.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000200.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000201.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000202.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000203.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000204.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000205.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000206.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000207.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000208.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000209.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000210.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000211.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000212.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000213.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000214.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000215.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000216.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000217.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000218.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000219.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000220.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000221.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000222.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000223.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000224.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000225.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000226.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000227.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000228.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000229.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000230.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000231.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000232.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000233.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000234.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000235.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000236.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000237.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000238.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000239.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000240.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000241.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000242.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000243.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000244.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000245.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000246.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000247.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000248.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000249.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000250.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000251.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000252.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000253.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000254.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000255.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000256.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000257.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000258.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000259.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000260.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000261.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000262.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000263.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000264.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000265.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000266.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000267.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000268.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000269.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000270.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000271.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000272.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000273.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000274.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000275.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000276.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000277.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000278.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000279.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000280.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000281.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000282.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000283.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000284.png
#   inflating: /content/datasets/train/GOPR0884_11_00/sharp/000285.png

# %%
import os
import torch
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset, random_split
from PIL import Image

def transform_sharp(image):
    # Provides a 720x1280 image for sharp_img
    return transforms.Compose([
        transforms.Resize((720, 1280)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])(image)

def transform_blur(image):
    # Provide a 360x640 image to blur_img
    return transforms.Compose([
        transforms.Resize((360, 640)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])(image)

class CustomDataset(Dataset):
    def __init__(self, root_dir, mix_ratio=0.5):
        self.root_dir = os.path.expanduser(root_dir)
        self.mix_ratio = mix_ratio
        self.samples = self._load_samples()

    def _load_samples(self):
        samples = []
        for subdir in sorted(os.listdir(self.root_dir)):
            subdir_path = os.path.join(self.root_dir, subdir)
            if os.path.isdir(subdir_path):
                sharp_imgs = sorted(os.listdir(os.path.join(subdir_path, 'sharp')))
                blur_imgs = sorted(os.listdir(os.path.join(subdir_path, 'blur')))
                blur_gamma_imgs = sorted(os.listdir(os.path.join(subdir_path, 'blur_gamma')))

                for sharp_img, blur_img, blur_gamma_img in zip(sharp_imgs, blur_imgs, blur_gamma_imgs):
                    sharp_path = os.path.join(subdir_path, 'sharp', sharp_img)
                    blur_path = os.path.join(subdir_path, 'blur', blur_img)
                    blur_gamma_path = os.path.join(subdir_path, 'blur_gamma', blur_gamma_img)
                    samples.append((sharp_path, blur_path, blur_gamma_path))
        return samples

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        sharp_path, blur_path, blur_gamma_path = self.samples[idx]
        sharp_img = Image.open(sharp_path).convert('RGB')
        blur_img = Image.open(blur_path).convert('RGB')
        blur_gamma_img = Image.open(blur_gamma_path).convert('RGB')

        # Mix blur and blur_gamma images
        blur_img = Image.blend(blur_img, blur_gamma_img, self.mix_ratio)
        sharp_img = transform_sharp(sharp_img)
        blur_img = transform_blur(blur_img)

        return blur_img, sharp_img

# Function used to save model output
def save_model_output(output, filename):
    output = output.cpu().detach()
    output_img = transforms.ToPILImage()(output).convert('RGB')
    output_img.save(filename)

train_dataset = CustomDataset(root_dir='/content/datasets/train')
# Split the data set into training set and validation set
train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])


train_loader = DataLoader(
    train_subset,
    batch_size=2,
    shuffle=True,
    num_workers=8
)
val_loader = DataLoader(
    val_subset,
    batch_size=2,
    shuffle=False,
    num_workers=8
)

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision.models import mobilenet_v3_small, MobileNet_V3_Small_Weights
import torch.distributed as distance
from torch.cuda.amp import GradScaler, autocast

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

#def Perceptual Loss by MobileNet
class PerceptualLoss(nn.Module):
    def __init__(self):
        super(PerceptualLoss, self).__init__()
        self.mobilenet = mobilenet_v3_small(weights=MobileNet_V3_Small_Weights.DEFAULT).features
        self.mobilenet.eval()
        for param in self.mobilenet.parameters():
            param.requires_grad = False

    def forward(self, input, target):
        input_features = self.mobilenet(input)
        target_features = self.mobilenet(target)
        # Resize if necessary
        if input_features.shape[2:] != target_features.shape[2:]:
            input_features = F.interpolate(input_features, size=target_features.shape[2:], mode='bilinear', align_corners=False)

        loss = nn.functional.mse_loss(input_features, target_features)
        return loss

# %%
#Define the DnCNN Model
class DnCNN(nn.Module):
    def __init__(self, channels, num_of_layers=17):
        super(DnCNN, self).__init__()
        kernel_size = 3
        padding = 1
        features = 64
        layers = []

        # Initial convolution layer
        layers.append(nn.Conv2d(in_channels=channels, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
        layers.append(nn.ReLU(inplace=True))

        # Middle layers
        for _ in range(num_of_layers - 2):
            layers.append(nn.Conv2d(in_channels=features, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
            layers.append(nn.BatchNorm2d(features))
            layers.append(nn.ReLU(inplace=True))

        # Final convolution layer
        layers.append(nn.Conv2d(in_channels=features, out_channels=channels, kernel_size=kernel_size, padding=padding, bias=False))

        self.dncnn = nn.Sequential(*layers)

    def forward(self, x):
        out = self.dncnn(x)
        return out

# %%
import torch.nn as nn
import torch.nn.functional as F

class Down(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)

class Up(nn.Module):
    def __init__(self, in_channels, out_channels, bilinear=True):
        super().__init__()

        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        else:
            self.up = nn.ConvTranspose2d(in_channels // 2, in_channels // 2, kernel_size=2, stride=2)

        self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2, diffY // 2, diffY - diffY // 2])

        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)

class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        return self.conv(x)

# %%
# Definite U-Net
class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)

class UNet(nn.Module):
    def __init__(self, n_channels, n_classes):
        super(UNet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes

        self.inc = DoubleConv(n_channels, 64)
        self.down1 = Down(64, 128)
        self.down2 = Down(128, 256)
        self.down3 = Down(256, 512)
        self.down4 = Down(512, 512)
        self.up1 = Up(1024, 256)
        self.up2 = Up(512, 128)
        self.up3 = Up(256, 64)
        self.up4 = Up(128, 64)
        self.outc = OutConv(64, n_classes)

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        logits = self.outc(x)
        return logits

# %%
# Residual Block
class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(channels, channels, kernel_size=3, padding=1)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(channels, channels, kernel_size=3, padding=1)

    def forward(self, x):
        residual = self.conv1(x)
        residual = self.relu(residual)
        residual = self.conv2(residual)
        return x + residual

# EDSR Model, use scale_factor to choose scale
class EDSR(nn.Module):
    def __init__(self, scale_factor=2, num_channels=3, num_residual_blocks=16):
        super(EDSR, self).__init__()
        self.num_channels = num_channels

        # First layer
        self.conv1 = nn.Conv2d(num_channels, 64, kernel_size=9, padding=4)

        # Residual blocks
        self.residual_blocks = nn.Sequential(*[ResidualBlock(64) for _ in range(num_residual_blocks)])

        # Second conv layer post residual blocks
        self.conv2 = nn.Conv2d(64, 64, kernel_size=3, padding=1)

        # Upsampling layers
        self.upsampling = nn.Sequential(
            nn.Conv2d(64, 256, kernel_size=3, padding=1),
            nn.PixelShuffle(upscale_factor=scale_factor),
            nn.ReLU(inplace=True)
        )

        # Output layer
        self.conv3 = nn.Conv2d(64, num_channels, kernel_size=9, padding=4)

    def forward(self, x):
        out = self.conv1(x)
        residual = out
        out = self.residual_blocks(out)
        out = self.conv2(out)
        out = out + residual  # Element-wise sum
        out = self.upsampling(out)
        out = self.conv3(out)
        return out

#Create EDSR model instance
model = EDSR(scale_factor=2, num_channels=3, num_residual_blocks=16)

# %%
# Add SobelEdgeLoss
class SobelEdgeLoss(nn.Module):
    def __init__(self):
        super(SobelEdgeLoss, self).__init__()
        sobel_x = torch.tensor([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]], dtype=torch.float32).view(1, 1, 3, 3)
        sobel_y = torch.tensor([[-1, -2, -1], [0, 0, 0], [1, 2, 1]], dtype=torch.float32).view(1, 1, 3, 3)
        self.sobel_x = sobel_x.repeat(3, 1, 1, 1).to(device)
        self.sobel_y = sobel_y.repeat(3, 1, 1, 1).to(device)

    def forward(self, input, target):
        input_x = F.conv2d(input, self.sobel_x, padding=1, groups=3)
        input_y = F.conv2d(input, self.sobel_y, padding=1, groups=3)
        target_x = F.conv2d(target, self.sobel_x, padding=1, groups=3)
        target_y = F.conv2d(target, self.sobel_y, padding=1, groups=3)

        input_edge = torch.sqrt(input_x ** 2 + input_y ** 2)
        target_edge = torch.sqrt(target_x ** 2 + target_y ** 2)

        loss = F.mse_loss(input_edge, target_edge)
        return loss

# %%
dncnn = DnCNN(channels=3).to(device)
unet = UNet(n_channels=3, n_classes=3).to(device)
edsr = EDSR(scale_factor=2, num_channels=3, num_residual_blocks=16)

# %%
 dncnn.load_state_dict(torch.load('/content/drive/MyDrive/model/DnCNN/denoising_DnCNN3.pth'))
 unet.load_state_dict(torch.load('/content/drive/MyDrive/model/UNet/deblured_UNet4.pth'))
 edsr.load_state_dict(torch.load('/content/drive/MyDrive/model/EDSR/SuperResolution_EDSR.pth'))

# %%
class JointModel(nn.Module):
    def __init__(self, dncnn, unet, edsr):
        super(JointModel, self).__init__()
        self.dncnn = dncnn
        self.unet = unet
        self.edsr = edsr

    def forward(self, x):
        x = self.dncnn(x)  # denoised
        x = self.unet(x)  # deblured
        x = self.edsr(x)  # super resolution
        return x

joint_model = JointModel(dncnn, unet, edsr).to(device)

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
# Creat model and Adam optimizer
mse_criterion = nn.MSELoss()
perceptual_criterion = PerceptualLoss().to(device)
optimizer = torch.optim.Adam(joint_model.parameters(), lr=0.00001)

# Initialize the ReduceLROnPlateau scheduler
scheduler = ReduceLROnPlateau(optimizer, 'min', factor=0.1, patience=5, verbose=True)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_small-047dcff4.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_small-047dcff4.pth
# 100%|██████████| 9.83M/9.83M [00:00<00:00, 126MB/s]

# %%
#Defining Loss Function Weights
mse_weight = 1.0
perceptual_weight = 0.1

# %%
# Train model
def train_model(joint_model, train_loader, val_loader, mse_criterion, perceptual_criterion, optimizer, num_epochs=300, early_stopping_tolerance=15):
    best_val_loss = float('inf')
    no_improvement_count = 0  # Early stopping counter

    sobel_criterion = SobelEdgeLoss().to(device)
    sobel_weight = 0.05

    scaler = GradScaler()
    for epoch in range(num_epochs):
        joint_model.train()
        running_loss = 0.0

        for blur_img, transformed_sharp_img in train_loader:
            blur_img = blur_img.to(device)
            transformed_sharp_img = transformed_sharp_img.to(device)

            optimizer.zero_grad()

           # Performing forward propagation using the autocast context
            with autocast():
                outputs = joint_model(blur_img)
                mse_loss = mse_criterion(outputs, transformed_sharp_img)
                perceptual_loss = perceptual_criterion(outputs, transformed_sharp_img)
                sobel_loss = sobel_criterion(outputs, transformed_sharp_img)
                total_loss = mse_weight * mse_loss + perceptual_weight * perceptual_loss + sobel_weight * sobel_loss

            # Performing backward propagation and optimization using GradScaler
            scaler.scale(total_loss).backward()
            scaler.step(optimizer)
            scaler.update()

            running_loss += total_loss.item() * blur_img.size(0)
        train_loss = running_loss / len(train_loader.dataset)

        # Validation test
        joint_model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for blur_img, transformed_sharp_img in val_loader:
                blur_img = blur_img.to(device)
                transformed_sharp_img = transformed_sharp_img.to(device)
                outputs = joint_model(blur_img)
                mse_loss = mse_criterion(outputs, transformed_sharp_img)
                perceptual_loss = perceptual_criterion(outputs, transformed_sharp_img)
                sobel_loss = sobel_criterion(outputs, transformed_sharp_img)
                total_loss = mse_weight * mse_loss + perceptual_weight * perceptual_loss + sobel_weight * sobel_loss
                val_loss += total_loss.item() * blur_img.size(0)

        val_loss /= len(val_loader.dataset)
        print(f'Epoch {epoch+1}/{num_epochs}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}')

        scheduler.step(val_loss)
        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            no_improvement_count = 0
        else:
            no_improvement_count += 1
            if no_improvement_count >= early_stopping_tolerance:
                print("Stopping early due to no improvement in validation loss")
                break

    return joint_model

train_model(joint_model, train_loader, val_loader, mse_criterion, perceptual_criterion, optimizer, num_epochs=300, early_stopping_tolerance=8)
# Out:
# Epoch 1/300, Training Loss: 0.2317, Validation Loss: 0.1829
# Epoch 2/300, Training Loss: 0.2353, Validation Loss: 0.1718
# Epoch 3/300, Training Loss: 0.2359, Validation Loss: 0.1739
# Epoch 4/300, Training Loss: 0.2334, Validation Loss: 0.1777
# Epoch 5/300, Training Loss: 0.2336, Validation Loss: 0.1791
# Epoch 6/300, Training Loss: 0.2343, Validation Loss: 0.1722
# Epoch 7/300, Training Loss: 0.2330, Validation Loss: 0.1812
# Epoch 8/300, Training Loss: 0.2342, Validation Loss: 0.1830
# Epoch 00008: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 9/300, Training Loss: 0.2353, Validation Loss: 0.1751
# Epoch 10/300, Training Loss: 0.2358, Validation Loss: 0.1736
# Stopping early due to no improvement in validation loss
# JointModel(
#   (dncnn): DnCNN(
#     (dncnn): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU(inplace=True)
#       (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU(inplace=True)
#       (8): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): ReLU(inplace=True)
#       (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (13): ReLU(inplace=True)
#       (14): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (15): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (16): ReLU(inplace=True)
#       (17): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (18): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (19): ReLU(inplace=True)
#       (20): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (21): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (22): ReLU(inplace=True)
#       (23): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (24): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (25): ReLU(inplace=True)
#       (26): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (27): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (28): ReLU(inplace=True)
#       (29): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (30): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (31): ReLU(inplace=True)
#       (32): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (33): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (34): ReLU(inplace=True)
#       (35): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (36): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (37): ReLU(inplace=True)
#       (38): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (39): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (40): ReLU(inplace=True)
#       (41): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (42): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (43): ReLU(inplace=True)
#       (44): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (45): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (46): ReLU(inplace=True)
#       (47): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (unet): UNet(
#     (inc): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (down1): Down(
#       (maxpool_conv): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): DoubleConv(
#           (double_conv): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (5): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (down2): Down(
#       (maxpool_conv): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): DoubleConv(
#           (double_conv): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (5): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (down3): Down(
#       (maxpool_conv): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): DoubleConv(
#           (double_conv): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (5): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (down4): Down(
#       (maxpool_conv): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): DoubleConv(
#           (double_conv): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (5): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (up1): Up(
#       (up): Upsample(scale_factor=2.0, mode='bilinear')
#       (conv): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#     (up2): Up(
#       (up): Upsample(scale_factor=2.0, mode='bilinear')
#       (conv): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#     (up3): Up(
#       (up): Upsample(scale_factor=2.0, mode='bilinear')
#       (conv): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#     (up4): Up(
#       (up): Upsample(scale_factor=2.0, mode='bilinear')
#       (conv): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#     (outc): OutConv(
#       (conv): Conv2d(64, 3, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (edsr): EDSR(
#     (conv1): Conv2d(3, 64, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#     (residual_blocks): Sequential(
#       (0): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (2): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (3): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (4): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (5): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (6): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (7): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (8): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (9): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (10): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (11): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (12): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (13): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (14): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (15): ResidualBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (upsampling): Sequential(
#       (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): PixelShuffle(upscale_factor=2)
#       (2): ReLU(inplace=True)
#     )
#     (conv3): Conv2d(64, 3, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#   )
# )

# %%
# Save model
if torch.cuda.is_available() and torch.cuda.current_device() == 0:
    model_path = '/content/drive/MyDrive/model/joint_model.pth'
    model_dir = os.path.expanduser(os.path.dirname(model_path))

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    torch.save(joint_model.state_dict(), os.path.expanduser(model_path))
    print(f"Model saved to {model_path}.")
# Out:
# Model saved to /content/drive/MyDrive/model/joint_model.pth.

# %%
# Inverse normalization transformation
inv_normalize = transforms.Normalize(
    mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
    std=[1/0.229, 1/0.224, 1/0.225]
)

# %%
from skimage.metrics import peak_signal_noise_ratio as compare_psnr
from skimage.metrics import structural_similarity as compare_ssim
from skimage import img_as_float
import torch

# Initialize the sum of PSNR and SSIM
total_psnr_sharp = 0
total_ssim_sharp = 0
total_psnr_blur = 0
total_ssim_blur = 0
num_images = 0

with torch.no_grad():
    for blur_img, sharp_img in val_loader:
        blur_img = blur_img.to(device)
        sharp_img = sharp_img.to(device)

        deblured_img = joint_model(blur_img)

# Traverse the image to calculate PSNR and SSIM
        for i in range(blur_img.size(0)):
            deblured = inv_normalize(deblured_img[i]).clamp(0, 1)
            sharp = inv_normalize(sharp_img[i]).clamp(0, 1)
            blur = inv_normalize(blur_img[i]).clamp(0, 1)

            deblured_np = deblured.cpu().numpy().transpose(1, 2, 0)
            sharp_np = sharp.cpu().numpy().transpose(1, 2, 0)
            blur_np = blur.cpu().numpy().transpose(1, 2, 0)

    # Calculate PSNR and SSIM
            psnr_sharp = compare_psnr(deblured_np, sharp_np)
            ssim_sharp = compare_ssim(deblured_np, sharp_np, multichannel=True)

            total_psnr_sharp += psnr_sharp
            total_ssim_sharp += ssim_sharp
            num_images += 1

# Calculate average PSNR and SSIM
avg_psnr_sharp = total_psnr_sharp / num_images
avg_ssim_sharp = total_ssim_sharp / num_images


print(f'Average PSNR (Deblured vs Sharp): {avg_psnr_sharp}')
print(f'Average SSIM (Deblured vs Sharp): {avg_ssim_sharp}')
# Out:
# <ipython-input-19-cd993876b209>:32: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   ssim_sharp = compare_ssim(deblured_np, sharp_np, multichannel=True)
# Average PSNR (Deblured vs Sharp): 24.629592931317745
# Average SSIM (Deblured vs Sharp): 0.8670229522462696

# %%
from concurrent.futures import ProcessPoolExecutor
import os
import torch
from torchvision import transforms, utils
from PIL import Image
import torchvision

def process_blur_images(joint_model_path, dataset_root, output_folder):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    joint_model.load_state_dict(torch.load(joint_model_path, map_location=device))
    joint_model.eval()
    joint_model.to(device)

    os.makedirs(output_folder, exist_ok=True)

    img_counter = 1
    for subdir in sorted(os.listdir(dataset_root)):
        blur_folder = os.path.join(dataset_root, subdir, 'blur')
        if os.path.isdir(blur_folder):
            for blur_img_name in sorted(os.listdir(blur_folder)):
                blur_img_path = os.path.join(blur_folder, blur_img_name)
                blur_img = Image.open(blur_img_path).convert('RGB')
                blur_img_tensor = transform_blur(blur_img).unsqueeze(0).to(device)

                with torch.no_grad():
                    output = joint_model(blur_img_tensor)

                output = inv_normalize(output.squeeze(0)).cpu()

                output_filename = f'img_{img_counter:04d}.png'
                output_image_path = os.path.join(output_folder, output_filename)
                utils.save_image(output, output_image_path)

                img_counter += 1

process_blur_images('/content/drive/MyDrive/model/joint_model.pth', '/content/datasets/train', '/content/image/processed_images')

# %%
from PIL import Image, ImageFilter
import os

def apply_unsharp_mask_and_save(input_folder, output_folder, radius=2, percent=150, threshold=3):
    # Create the output folder if it does not exist
    os.makedirs(output_folder, exist_ok=True)

    # Process and save each image
    for img_name in os.listdir(input_folder):
        img_path = os.path.join(input_folder, img_name)
        with Image.open(img_path) as img:
            # Apply Unsharp Mask
            sharpened_img = img.filter(ImageFilter.UnsharpMask(radius=radius, percent=percent, threshold=threshold))

            # Save the sharpened image
            output_img_path = os.path.join(output_folder, img_name)
            sharpened_img.save(output_img_path)

# Use the function
apply_unsharp_mask_and_save('/content/image/processed_images', '/content/image/sharpened_images')

# %%
import shutil
source_folder = '/content/image'
zip_file_path = '/content/drive/MyDrive/image.zip'
shutil.make_archive(zip_file_path[:-4], 'zip', source_folder)
# Out:
# '/content/drive/MyDrive/image.zip'
